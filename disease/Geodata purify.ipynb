# %%
import pandas as pd

# %%
geo_dtap = pd.read_csv('unclean/geo_dtap.csv')
geo_dtap.drop(columns=['Unnamed: 0', 'total'], inplace=True)
geo_dtap
# Out:
#               name        number                                  address  \
# 0     21세기소아청소년과의원  033-745-0815                       강원도 원주시 봉화로 27 단계동
# 1     365성모가정의학과의원  033-251-3500               강원도 춘천시 후석로 352 후평동 국제빌딩2층
# 2     Dr.하석우의한사랑의원  033-522-2244               강원도 동해시 효자남길 16 동회동 월드상가1층
# 3           강릉아산병원  033-610-3799                       강원도 강릉시 사천면 방동길 38
# 4          강원대학교병원  033-258-2000                      강원도 춘천시 백령로 156 효자동
# 5        강원도 삼척의료원  033-572-1141                     강원도 삼척시 오십천로 418 남양동
# 6        강원도 영월의료원  033-370-9128                      강원도 영월군 영월읍 중앙1로 59
# 7        강원도 원주의료원  033-760-4546                     강원도 원주시 서원대로 387 개운동
# 8         강원도강릉의료원  033-610-1271                  강원도 강릉시 경강로 2007-  2007
# 9       강훈소아청소년과의원  033-744-7579          강원도 원주시 입춘로 110 반곡동 파라다이스프라자301
# 10      개성소아청소년과의원  033-635-3229                     강원도 속초시 동해대로 4215 교동
# 11      고석연가정의학과의원  033-254-0121                      강원도 춘천시 후석로 244 후평동
# ...

# %%
geo_dtap = geo_dtap[geo_dtap.lat != 0]

# %%
geo_dtap
# Out:
#               name        number                                  address  \
# 0     21세기소아청소년과의원  033-745-0815                       강원도 원주시 봉화로 27 단계동
# 1     365성모가정의학과의원  033-251-3500               강원도 춘천시 후석로 352 후평동 국제빌딩2층
# 2     Dr.하석우의한사랑의원  033-522-2244               강원도 동해시 효자남길 16 동회동 월드상가1층
# 3           강릉아산병원  033-610-3799                       강원도 강릉시 사천면 방동길 38
# 4          강원대학교병원  033-258-2000                      강원도 춘천시 백령로 156 효자동
# 5        강원도 삼척의료원  033-572-1141                     강원도 삼척시 오십천로 418 남양동
# 6        강원도 영월의료원  033-370-9128                      강원도 영월군 영월읍 중앙1로 59
# 7        강원도 원주의료원  033-760-4546                     강원도 원주시 서원대로 387 개운동
# 9       강훈소아청소년과의원  033-744-7579          강원도 원주시 입춘로 110 반곡동 파라다이스프라자301
# 10      개성소아청소년과의원  033-635-3229                     강원도 속초시 동해대로 4215 교동
# 11      고석연가정의학과의원  033-254-0121                      강원도 춘천시 후석로 244 후평동
# 12            구곡의원  033-734-6180                강원도 원주시 늘품로 6 단구동 청솔1차아파트
# ...

# %%
geo_dtap.reset_index(drop=True, inplace=True)

# %%
geo_dtap.to_csv('clean/geo_dtap.csv')

# %%
geo_hib = pd.read_csv('unclean/geo_hib.csv')
geo_hib.drop(columns=['Unnamed: 0', 'total'], inplace=True)
geo_hib = geo_hib[1:4563]

geo_hib = geo_hib[geo_hib.lat != 0]
geo_hib.reset_index(drop=True, inplace=True)
geo_hib.to_csv('clean/geo_hib.csv')

# %%
import pandas as pd

# %%
geo_hpeb = pd.read_csv('geo_hpeb.csv')
geo_hpeb.drop(columns=['Unnamed: 0'], inplace=True)
geo_hpeb
# geo_hib = geo_hib[1:4563]

# geo_hib = geo_hib[geo_hib.lat != 0]
# geo_hib.reset_index(drop=True, inplace=True)
# geo_hib.to_csv('clean/geo_hib.csv')
# Out:
#               name         number                                   address  \
# 0            병/의원명           전화번호                                        주소
# 1     21세기소아청소년과의원   033-745-0815                            강원도 원주시 봉화로 27
# 2     365성모가정의학과의원   033-251-3500                           강원도 춘천시 후석로 352
# 3     Dr.하석우의한사랑의원   033-522-2244                           강원도 동해시 효자남길 16
# 4           강릉아산병원   033-610-3799                        강원도 강릉시 사천면 방동길 38
# 5          강원대학교병원   033-258-2000                           강원도 춘천시 백령로 156
# 6        강원도 삼척의료원   033-572-1141                          강원도 삼척시 오십천로 418
# 7        강원도 영월의료원   033-370-9128                       강원도 영월군 영월읍 중앙1로 59
# 8        강원도 원주의료원   033-760-4546                          강원도 원주시 서원대로 387
# 9         강원도강릉의료원   033-610-1271                        강원도 강릉시 경강로 2007-
# 10        강원도속초의료원   033-630-6000                           강원도 속초시 영랑호반길 3
# ...

# %%
geo_hpeb[geo_hpeb['add2'].isna()]
# Out:
#                name         number                                   address  \
# 0             병/의원명           전화번호                                        주소
# 1      21세기소아청소년과의원   033-745-0815                            강원도 원주시 봉화로 27
# 4            강릉아산병원   033-610-3799                        강원도 강릉시 사천면 방동길 38
# 5           강원대학교병원   033-258-2000                           강원도 춘천시 백령로 156
# 6         강원도 삼척의료원   033-572-1141                          강원도 삼척시 오십천로 418
# 7         강원도 영월의료원   033-370-9128                       강원도 영월군 영월읍 중앙1로 59
# 8         강원도 원주의료원   033-760-4546                          강원도 원주시 서원대로 387
# 9          강원도강릉의료원   033-610-1271                        강원도 강릉시 경강로 2007-
# 10         강원도속초의료원   033-630-6000                           강원도 속초시 영랑호반길 3
# 12       개성소아청소년과의원   033-635-3229                         강원도 속초시 동해대로 4215
# 13         고려산부인과의원   033-635-3579                            강원도 속초시 중앙로 96
# ...

# %%
hp1 = geo_hpeb[geo_hpeb['add2'].isna()]

# %%
hp1.drop('add2',inplace=True,axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
hp1_1 = hp1[hp1['add1'].isna()]

# %%
hp1_1.drop('add1',inplace=True,axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
pd.concat

# %%
hp1_2 = hp1[hp1['add1'].isna() == False]

# %%
hp1_1.head()
# Out:
#              name         number                      address         lat  \
# 0           병/의원명           전화번호                           주소    0.000000
# 39  미성의료재단 아름다운병원   033-430-9999     강원도 홍천군 홍천읍 홍천로 342-10    127.883193
# 42         밝은미래의원   033-481-2575   강원도 양구군 양구읍 사명길 32  밝은미래의원  127.988401
# 45     부부소아청소년과의원   033-746-5988         강원도 원주시 문막읍 왕건로 48    127.829311
# 50           성가의원   033-372-4888       강원도 영월군 영월읍 중앙로 33  번지  128.467422
#
#           lng
# 0    0.000000
# 39  37.688119
# 42  38.103708
# 45  37.323879
# 50  37.183707

# %%
hp1_2.head()
# Out:
#            name         number                   address         lat  \
# 1  21세기소아청소년과의원   033-745-0815    강원도 원주시 봉화로 27 (단계동)    127.928326
# 4        강릉아산병원   033-610-3799     강원도 강릉시 사천면 방동길 38  -  128.857841
# 5       강원대학교병원   033-258-2000   강원도 춘천시 백령로 156 (효자동)    127.744891
# 6     강원도 삼척의료원   033-572-1141   강원도 삼척시 오십천로 418 (남양동)   129.163802
# 7     강원도 영월의료원   033-370-9128     강원도 영월군 영월읍 중앙1로 59    128.465239
#
#          lng
# 1  37.346931
# 4  37.818433
# 5  37.875161
# 6  37.440302
# 7  37.186453

# %%
new_pd = pd.concat([hp1_1,hp1_2])

# %%
new_pd = new_pd[new_pd['lat']!=0]

# %%
type(new_pd)
# Out:
# pandas.core.frame.DataFrame

# %%
new_pd.to_csv('hpeb1.csv')

# %%
hp2.to_csv('hpeb2.csv')

# %%
pd.concat(new_pd,hp2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-2691f17f7ca4> in <module>()
# ----> 1 pd.concat(new_pd,hp2)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     239             raise TypeError('first argument must be an iterable of pandas '
# ...

# %%
hp1_2['address'] = hp1_2["address"].map(str) + hp1_2["add1"]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
hp1_2.drop('add1',inplace=True,axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
hp1_2
# Out:
#               name         number                                    address  \
# 1     21세기소아청소년과의원   033-745-0815                     강원도 원주시 봉화로 27 (단계동)
# 4           강릉아산병원   033-610-3799                      강원도 강릉시 사천면 방동길 38  -
# 5          강원대학교병원   033-258-2000                    강원도 춘천시 백령로 156 (효자동)
# 6        강원도 삼척의료원   033-572-1141                    강원도 삼척시 오십천로 418 (남양동)
# 7        강원도 영월의료원   033-370-9128                      강원도 영월군 영월읍 중앙1로 59
# 8        강원도 원주의료원   033-760-4546                    강원도 원주시 서원대로 387 (개운동)
# 9         강원도강릉의료원   033-610-1271                     강원도 강릉시 경강로 2007- 2007
# 10        강원도속초의료원   033-630-6000                    강원도 속초시 영랑호반길 3 (영랑동)
# 12      개성소아청소년과의원   033-635-3229                   강원도 속초시 동해대로 4215 (교동)
# 13        고려산부인과의원   033-635-3579                     강원도 속초시 중앙로 96 (청학동)
# 14      고석연가정의학과의원   033-254-0121                    강원도 춘천시 후석로 244 (후평동)
# ...

# %%
hp2 = geo_hpeb[geo_hpeb['add2'].isna() == False]

# %%
hp2['add1'] = hp2["add1"].map(str) + hp2["add2"]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
hp2['address'] = hp2["address"].map(str) + hp2["add1"]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
hp2.drop('add1',inplace=True,axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
hp2.head()
# Out:
#             name         number                             address  \
# 2   365성모가정의학과의원   033-251-3500     강원도 춘천시 후석로 352 (후평동 국제빌딩)  2층
# 3   Dr.하석우의한사랑의원   033-522-2244     강원도 동해시 효자남길 16 (동회동 월드상가)  1층
# 11    강훈소아청소년과의원   033-744-7579   강원도 원주시 입춘로 110 (반곡동 파라다이스프라자 301
# 15          구곡의원   033-734-6180       강원도 원주시 늘품로 6 (단구동 청솔1차아파트)
# 18    글로리아산부인과의원   033-532-0050    강원도 동해시 천곡로 86-2 (천곡동 대륜빌딩)  3층
#
#            lat        lng
# 2   127.748685  37.882097
# 3   129.108727  37.487701
# 11  127.981673  37.323415
# 15  127.950287  37.320936
# 18  129.115022  37.522866

# %%
type(geo_hpeb.iloc[1,4])
# Out:
# float

# %%
geo_hpeb
# Out:
#               name         number                                   address  \
# 0            병/의원명           전화번호                                        주소
# 1     21세기소아청소년과의원   033-745-0815                            강원도 원주시 봉화로 27
# 2     365성모가정의학과의원   033-251-3500                           강원도 춘천시 후석로 352
# 3     Dr.하석우의한사랑의원   033-522-2244                           강원도 동해시 효자남길 16
# 4           강릉아산병원   033-610-3799                        강원도 강릉시 사천면 방동길 38
# 5          강원대학교병원   033-258-2000                           강원도 춘천시 백령로 156
# 6        강원도 삼척의료원   033-572-1141                          강원도 삼척시 오십천로 418
# 7        강원도 영월의료원   033-370-9128                       강원도 영월군 영월읍 중앙1로 59
# 8        강원도 원주의료원   033-760-4546                          강원도 원주시 서원대로 387
# 9         강원도강릉의료원   033-610-1271                        강원도 강릉시 경강로 2007-
# 10        강원도속초의료원   033-630-6000                           강원도 속초시 영랑호반길 3
# ...

# %%
geo_hpeb['address'] = geo_hpeb["address"].map(str) + geo_hpeb["add1"]

# %%
geo_hpeb.head()
# Out:
#            name         number                           address  \
# 0         병/의원명           전화번호                               NaN
# 1  21세기소아청소년과의원   033-745-0815                               NaN
# 2  365성모가정의학과의원   033-251-3500   강원도 춘천시 후석로 352 (후평동 국제빌딩)  2층
# 3  Dr.하석우의한사랑의원   033-522-2244   강원도 동해시 효자남길 16 (동회동 월드상가)  1층
# 4        강릉아산병원   033-610-3799                               NaN
#
#                add1         add2         lat        lng
# 0               NaN          NaN    0.000000   0.000000
# 1               NaN          NaN  127.928326  37.346931
# 2   (후평동 국제빌딩)  2층    국제빌딩)  2층   127.748685  37.882097
# 3   (동회동 월드상가)  1층    월드상가)  1층   129.108727  37.487701
# 4               NaN          NaN  128.857841  37.818433

# %%
j1 = pd.read_json('japanEncephalitis1.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-ae24c19f6017> in <module>()
# ----> 1 j1 = pd.read_json('japanEncephalitis1.json')
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in read(self)
#     527             )
#     528         else:
# --> 529             obj = self._get_object_parser(self.data)
#     530         self.close()
#     531         return obj
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in _get_object_parser(self, json)
# ...
